# %% [markdown]
# Setup & Custom Visualizations

# %%
import sys
import os
import pandas as pd
import joblib
from sklearn.metrics import accuracy_score, classification_report

# Path setup
project_root = os.path.abspath('..')
src_path = os.path.join(project_root, 'src')

if src_path not in sys.path:
    sys.path.insert(0, src_path)

from heart_utils import plot_confusion_matrix, plot_roc_curve

# %% [markdown]
# Loading for Evaluation

# %%
X_test = pd.read_csv('../data/processed/X_test.csv')
y_test = pd.read_csv('../data/processed/y_test.csv').values.ravel()
model = joblib.load('../models/trained_model.pkl')

y_pred = model.predict(X_test)
y_probs = model.predict_proba(X_test)[:, 1]

# %% [markdown]
# Performance Analysis (Plots)

# %%
plot_confusion_matrix(y_test, y_pred, labels=['Healthy', 'Sick'], title='Heart Disease Confusion Matrix')
plot_roc_curve(y_test, y_probs, title='Model ROC Curve Analysis')
